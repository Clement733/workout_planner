# %%
import pandas as pd
import numpy as np
import csv

# %%
np.random.seed(0)

# %%
num_values = 100
chest = np.random.randint(60, 101, num_values)
chest = np.sort(chest)

# %%
shoulders = np.random.randint(6, 16, num_values)
shoulders = np.sort(shoulders)

# %%
legs = np.random.randint(60, 121, num_values)
legs = np.sort(legs)

# %%
back = np.random.randint(20, 81, num_values)
back = np.sort(back)

# %%
rep_chest = []
rep_count = {}
for repetition in chest:
    if repetition not in rep_count:
        rep_count[repetition] = 8
    else:
        rep_count[repetition] += 2
    rep_chest.append(rep_count[repetition])
rep_chest
# Out:
# [8,
#  10,
#  12,
#  14,
#  16,
#  18,
#  20,
#  8,
#  10,
#  12,
#  14,
#  8,
#  10,
#  12,
#  14,
#  8,
#  10,
#  12,
#  8,
#  10,
#  12,
#  14,
#  8,
#  10,
#  8,
#  8,
#  10,
#  12,
#  8,
#  8,
#  10,
#  12,
#  8,
#  10,
#  12,
#  8,
#  10,
#  12,
#  8,
#  10,
#  12,
#  8,
#  10,
#  12,
#  14,
#  8,
#  8,
#  10,
#  8,
#  10,
#  8,
#  10,
#  12,
#  8,
#  10,
#  12,
#  8,
#  10,
#  8,
#  10,
#  12,
#  14,
#  8,
#  10,
#  12,
#  14,
#  8,
#  8,
#  8,
#  8,
#  10,
#  8,
#  8,
#  10,
#  12,
#  8,
#  10,
#  8,
#  10,
#  12,
#  8,
#  10,
#  12,
#  14,
#  16,
#  18,
#  8,
#  10,
#  12,
#  14,
#  8,
#  8,
#  10,
#  12,
#  8,
#  10,
#  12,
#  14,
#  8,
#  10]

# %%
df_chest_improve = pd.DataFrame({'Chest_Weight': chest, 'Repetitions' : rep_chest})
df_chest_improve.head()
# Out:
#    Chest_Weight  Repetitions
# 0            60            8
# 1            60           10
# 2            60           12
# 3            60           14
# 4            60           16

# %%
rep_shoulders = []
rep_count = {}
max_rep = 15
for repetition in shoulders:
    if repetition not in rep_count:
        rep_count[repetition] = 8
    else:
        rep_count[repetition] += 1
    if rep_count[repetition] > max_rep:
        rep_count[repetition] = max_rep
    rep_shoulders.append(rep_count[repetition])
rep_shoulders
# Out:
# [8,
#  9,
#  10,
#  11,
#  12,
#  13,
#  14,
#  15,
#  15,
#  15,
#  15,
#  8,
#  9,
#  10,
#  11,
#  8,
#  9,
#  10,
#  11,
#  12,
#  13,
#  14,
#  15,
#  15,
#  15,
#  15,
#  15,
#  8,
#  9,
#  10,
#  11,
#  12,
#  13,
#  14,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  8,
#  9,
#  10,
#  11,
#  12,
#  13,
#  8,
#  9,
#  10,
#  11,
#  12,
#  13,
#  14,
#  8,
#  9,
#  10,
#  11,
#  12,
#  13,
#  14,
#  15,
#  15,
#  15,
#  15,
#  15,
#  8,
#  9,
#  10,
#  11,
#  12,
#  8,
#  9,
#  10,
#  11,
#  12,
#  13,
#  14,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  8,
#  9,
#  10,
#  11,
#  12,
#  13,
#  14,
#  15,
#  15,
#  15]

# %%
df_shoulders_improve = pd.DataFrame({'Shoulders_Weight': shoulders, 'Repetitions': rep_shoulders})
df_shoulders_improve
# Out:
#     Shoulders_Weight  Repetitions
# 0                  6            8
# 1                  6            9
# 2                  6           10
# 3                  6           11
# 4                  6           12
# ..               ...          ...
# 95                15           13
# 96                15           14
# 97                15           15
# 98                15           15
# 99                15           15
#
# [100 rows x 2 columns]

# %%
rep_legs = []
rep_count = {}
for repetition in legs:
    if repetition not in rep_count:
        rep_count[repetition] = 8
    else:
        rep_count[repetition] += 1
    rep_legs.append(rep_count[repetition])
rep_legs
# Out:
# [8,
#  8,
#  8,
#  9,
#  8,
#  9,
#  10,
#  11,
#  8,
#  9,
#  10,
#  8,
#  8,
#  9,
#  8,
#  8,
#  9,
#  10,
#  11,
#  12,
#  8,
#  8,
#  9,
#  8,
#  8,
#  8,
#  9,
#  10,
#  8,
#  9,
#  8,
#  8,
#  9,
#  8,
#  9,
#  10,
#  8,
#  8,
#  8,
#  8,
#  9,
#  8,
#  8,
#  9,
#  10,
#  11,
#  8,
#  9,
#  8,
#  9,
#  10,
#  11,
#  8,
#  9,
#  8,
#  8,
#  8,
#  9,
#  10,
#  8,
#  9,
#  10,
#  8,
#  9,
#  10,
#  8,
#  9,
#  8,
#  8,
#  9,
#  10,
#  11,
#  12,
#  8,
#  9,
#  8,
#  9,
#  8,
#  8,
#  9,
#  10,
#  8,
#  8,
#  9,
#  10,
#  8,
#  8,
#  9,
#  8,
#  9,
#  8,
#  9,
#  10,
#  8,
#  8,
#  8,
#  9,
#  10,
#  8,
#  8]

# %%
df_legs_improve = pd.DataFrame({'Legs_Weight': legs, 'Repetitions': rep_legs})
df_legs_improve
# Out:
#     Legs_Weight  Repetitions
# 0            60            8
# 1            61            8
# 2            62            8
# 3            62            9
# 4            63            8
# ..          ...          ...
# 95          113            8
# 96          113            9
# 97          113           10
# 98          116            8
# 99          120            8
#
# [100 rows x 2 columns]

# %%
rep_back = []
rep_count = {}
for repetition in legs:
    if repetition not in rep_count:
        rep_count[repetition] = 8
    else:
        rep_count[repetition] += 1
    rep_back.append(rep_count[repetition])
rep_back
# Out:
# [8,
#  8,
#  8,
#  9,
#  8,
#  9,
#  10,
#  11,
#  8,
#  9,
#  10,
#  8,
#  8,
#  9,
#  8,
#  8,
#  9,
#  10,
#  11,
#  12,
#  8,
#  8,
#  9,
#  8,
#  8,
#  8,
#  9,
#  10,
#  8,
#  9,
#  8,
#  8,
#  9,
#  8,
#  9,
#  10,
#  8,
#  8,
#  8,
#  8,
#  9,
#  8,
#  8,
#  9,
#  10,
#  11,
#  8,
#  9,
#  8,
#  9,
#  10,
#  11,
#  8,
#  9,
#  8,
#  8,
#  8,
#  9,
#  10,
#  8,
#  9,
#  10,
#  8,
#  9,
#  10,
#  8,
#  9,
#  8,
#  8,
#  9,
#  10,
#  11,
#  12,
#  8,
#  9,
#  8,
#  9,
#  8,
#  8,
#  9,
#  10,
#  8,
#  8,
#  9,
#  10,
#  8,
#  8,
#  9,
#  8,
#  9,
#  8,
#  9,
#  10,
#  8,
#  8,
#  8,
#  9,
#  10,
#  8,
#  8]

# %%
df_back_improve = pd.DataFrame({'Back_Weight': back, 'Repetitions': rep_back})
df_back_improve
# Out:
#     Back_Weight  Repetitions
# 0            20            8
# 1            20            8
# 2            20            8
# 3            21            9
# 4            23            8
# ..          ...          ...
# 95           79            8
# 96           79            9
# 97           80           10
# 98           80            8
# 99           80            8
#
# [100 rows x 2 columns]

# %%
df_improve = pd.concat([df_chest_improve, df_back_improve, df_shoulders_improve, df_legs_improve], axis = 1)
df_improve
# Out:
#     Chest_Weight  Repetitions  Back_Weight  Repetitions  Shoulders_Weight  \
# 0             60            8           20            8                 6
# 1             60           10           20            8                 6
# 2             60           12           20            8                 6
# 3             60           14           21            9                 6
# 4             60           16           23            8                 6
# ..           ...          ...          ...          ...               ...
# 95            99           10           79            8                15
# 96            99           12           79            9                15
# 97            99           14           80           10                15
# 98           100            8           80            8                15
# 99           100           10           80            8                15
#
#     Repetitions  Legs_Weight  Repetitions
# 0             8           60            8
# 1             9           61            8
# 2            10           62            8
# 3            11           62            9
# 4            12           63            8
# ..          ...          ...          ...
# 95           13          113            8
# 96           14          113            9
# 97           15          113           10
# 98           15          116            8
# 99           15          120            8
#
# [100 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 5))
sns.lineplot(data=df_chest_improve, x = 'Chest_Weight', y='Repetitions', ax = ax1)
ax1.set_title('Chest Improvement', fontsize=15)

sns.lineplot(data=df_shoulders_improve, x='Shoulders_Weight', y='Repetitions', ax = ax2)
ax2.set_title('Shoulders Improvement', fontsize=15)

sns.lineplot(data=df_legs_improve, x='Legs_Weight', y='Repetitions', ax=ax3)
ax3.set_title('Legs Improvement', fontsize=15)

sns.lineplot(data=df_back_improve, x='Back_Weight', y='Repetitions', ax=ax4)
ax4.set_title('Back Improvement', fontsize=15)

plt.tight_layout()
