# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Creation of male data

# %% [markdown]
# ## First male user (name = Robert)

# %% [markdown]
# ### Chest exercise data

# %%
num_values = 100
chest_fm = np.random.randint(60, 101, num_values)
chest_fm = np.sort(chest_fm)

# %%
rep_chest_fm = []
rep_count_fm = {}
for repetition in chest_fm:
    if repetition not in rep_count_fm:
        rep_count_fm[repetition] = 8
    else:
        rep_count_fm[repetition] += 2
    rep_chest_fm.append(rep_count_fm[repetition])
df_chest_fm = pd.DataFrame({'Chest_Weight': chest_fm, 'Chest_Repetitions' : rep_chest_fm})

# %% [markdown]
# ### Shoulders exercise data

# %%
shoulders_fm = np.random.randint(6, 16, num_values)
shoulders_fm = np.sort(shoulders_fm)

# %%
rep_shoulders_fm = []
rep_count_s = {}
max_rep = 15
for repetition in shoulders_fm:
    if repetition not in rep_count_fm:
        rep_count_s[repetition] = 8
    else:
        rep_count_s[repetition] += 1
    if rep_count_s[repetition] > max_rep:
        rep_count_s[repetition] = max_rep
    rep_shoulders_fm.append(rep_count_s[repetition])
df_shoulders_fm = pd.DataFrame({'Shoulders_Weight': shoulders_fm, 'Shoulders_Repetitions': rep_shoulders_fm})

# %% [markdown]
# ### Legs exercise data

# %%
legs_fm = np.random.randint(60, 121, num_values)
legs_fm = np.sort(legs_fm)

# %%
rep_legs_fm = []
rep_count = {}
for repetition in legs_fm:
    if repetition not in rep_count:
        rep_count[repetition] = 8
    else:
        rep_count[repetition] += 1
    rep_legs_fm.append(rep_count[repetition])
df_legs_fm = pd.DataFrame({'Legs_Weight': legs_fm, 'Legs_Repetitions': rep_legs_fm})

# %% [markdown]
# ### Back exercise data

# %%
back_fm = np.random.randint(20, 81, num_values)
back_fm = np.sort(back_fm)

# %%
rep_back_fm = []
rep_count = {}
for repetition in back_fm:
    if repetition not in rep_count:
        rep_count[repetition] = 8
    else:
        rep_count[repetition] += 1
    rep_back_fm.append(rep_count[repetition])
df_back_fm = pd.DataFrame({'Back_Weight': back_fm, 'Back_Repetitions': rep_back_fm})

# %% [markdown]
# ### Creation of full body data

# %%
list_robert = [chest_fm, rep_chest_fm, shoulders_fm, rep_shoulders_fm, legs_fm, rep_legs_fm, back_fm, rep_back_fm]

# %%
df_first_male = pd.concat([df_chest_fm, df_back_fm, df_shoulders_fm, df_legs_fm], axis = 1)
df_first_male
# Out:
#     Chest_Weight  Chest_Repetitions  Back_Weight  Back_Repetitions  \
# 0             61                  8           20                 8
# 1             62                  8           21                 8
# 2             62                 10           21                 9
# 3             62                 12           21                10
# 4             63                  8           22                 8
# ..           ...                ...          ...               ...
# 95            98                 16           78                 9
# 96            99                  8           79                 8
# 97            99                 10           79                 9
# 98            99                 12           80                 8
# 99           100                  8           80                 9
#
#     Shoulders_Weight  Shoulders_Repetitions  Legs_Weight  Legs_Repetitions
# 0                  6                      8           61                 8
# ...

# %% [markdown]
# ## Second male user (name = Roger)

# %% [markdown]
# ### Chest exercise data

# %%
chest_sm = np.random.randint(30, 61, num_values)
chest_sm = np.sort(chest_sm)
chest_rep_sm = []
chest_rc_sm = {}
for rep in chest_sm:
    if rep not in chest_rc_sm:
        chest_rc_sm[rep] = 8
    else:
        chest_rc_sm[rep] += 2
    chest_rep_sm.append(chest_rc_sm[rep])
df_chest_sm = pd.DataFrame({'Chest_Weight': chest_sm, 'Chest_Repetitions': chest_rep_sm})

# %% [markdown]
# ### Shoulders exercise data

# %%
shoulders_sm = np.random.randint(5*2, 11*2, num_values) /2
shoulders_sm = np.sort(shoulders_sm)
shoulders_rep_sm = []
shoulders_rc_sm = {}
for rep in shoulders_sm:
    if rep not in shoulders_rc_sm:
        shoulders_rc_sm[rep] = 8
    else:
        shoulders_rc_sm[rep] += 1
    if shoulders_rc_sm[rep] > 15:
        shoulders_rc_sm[rep] = 15
    shoulders_rep_sm.append(shoulders_rc_sm[rep])
df_shoulders_sm = pd.DataFrame({'Shoulders_Weight': shoulders_sm, 'Shoulders_Repetitions': shoulders_rep_sm})

# %% [markdown]
# ### Legs exercise data

# %%
legs_sm = np.random.randint(20, 61, num_values)
legs_sm = np.sort(legs_sm)
legs_rep_sm = []
legs_rc_sm = {}
for rep in legs_sm:
    if rep not in legs_rc_sm:
        legs_rc_sm[rep] = 8
    else:
        legs_rc_sm[rep] += 2
    legs_rep_sm.append(legs_rc_sm[rep])
df_legs_sm = pd.DataFrame({'Legs_Weight': legs_sm, 'Legs_Repetitions': legs_rep_sm})

# %% [markdown]
# ### Back exercise data

# %%
back_sm = np.random.randint(20, 51, num_values)
back_sm = np.sort(back_sm)
back_rep_sm = []
back_rc_sm = {}
for rep in back_sm:
    if rep not in back_rc_sm:
        back_rc_sm[rep] = 8
    else:
        back_rc_sm[rep] += 2
    back_rep_sm.append(back_rc_sm[rep])
df_back_sm = pd.DataFrame({'Back_Weight': back_sm, 'Back_Repetitions': back_rep_sm})

# %% [markdown]
# ### Creation of full body data

# %%
list_roger = [chest_sm, chest_rep_sm, shoulders_sm, shoulders_rep_sm, legs_sm, legs_rep_sm, back_sm, back_rep_sm]

# %%
df_second_male = pd.concat([df_chest_sm, df_shoulders_sm, df_legs_sm, df_back_sm], axis = 1)
df_second_male
# Out:
#     Chest_Weight  Chest_Repetitions  Shoulders_Weight  Shoulders_Repetitions  \
# 0             30                  8               5.0                      8
# 1             30                 10               5.0                      9
# 2             30                 12               5.0                     10
# 3             30                 14               5.0                     11
# 4             30                 16               5.0                     12
# ..           ...                ...               ...                    ...
# 95            59                 10              10.5                     13
# 96            59                 12              10.5                     14
# 97            59                 14              10.5                     15
# 98            59                 16              10.5                     15
# 99            60                  8              10.5                     15
#
# ...

# %% [markdown]
# ## Third male user (name = Justin)

# %% [markdown]
# ### Chest exercise data

# %%
chest_tm = np.random.randint(50, 121, num_values)
chest_tm = np.sort(chest_tm)
chest_rep_tm = []
chest_rc_tm = {}
for rep in chest_tm:
    if rep not in chest_rc_tm:
        chest_rc_tm[rep] = 8
    else:
        chest_rc_tm[rep] += 2
    chest_rep_tm.append(chest_rc_tm[rep])
df_chest_tm = pd.DataFrame({'Chest_Weight': chest_tm, 'Chest_Repetitions': chest_rep_tm})

# %% [markdown]
# ### Shoulders exercise data

# %%
shoulders_tm = np.random.randint(7, 21, num_values)
shoulders_tm = np.sort(shoulders_tm)
shoulders_rep_tm = []
shoulders_rc_tm = {}
for rep in shoulders_tm:
    if rep not in shoulders_rc_tm:
        shoulders_rc_tm[rep] = 8
    else:
        shoulders_rc_tm[rep] += 1
    if shoulders_rc_tm[rep] > 15:
        shoulders_rc_tm[rep] = 15
    shoulders_rep_tm.append(shoulders_rc_tm[rep])
df_shoulders_tm = pd.DataFrame({'Shoulders_Weight': shoulders_tm, 'Shoulders_Repetitions': shoulders_rep_tm})

# %% [markdown]
# ### Legs exercise data

# %%
legs_tm = np.random.randint(60, 141, num_values)
legs_tm = np.sort(legs_tm)
legs_rep_tm = []
legs_rc_tm = {}
for rep in legs_tm:
    if rep not in legs_rc_tm:
        legs_rc_tm[rep] = 8
    else:
        legs_rc_tm[rep] += 2
    legs_rep_tm.append(legs_rc_tm[rep])
df_legs_tm = pd.DataFrame({'Legs_Weight': legs_tm, 'Legs_Repetitions': legs_rep_tm})

# %% [markdown]
# ### Back exercise data

# %%
back_tm = np.random.randint(40, 111, num_values)
back_tm = np.sort(back_tm)
back_rep_tm = []
back_rc_tm = {}
for rep in back_tm:
    if rep not in back_rc_tm:
        back_rc_tm[rep] = 8
    else:
        back_rc_tm[rep] += 2
    back_rep_tm.append(back_rc_tm[rep])
df_back_tm = pd.DataFrame({'Back_Weight': back_tm, 'Back_Repetitions': back_rep_tm})

# %% [markdown]
# ### Creation of full body data

# %%
list_justin = [chest_tm, chest_rep_tm, shoulders_tm, shoulders_rep_tm, legs_tm, legs_rep_tm, back_tm, back_rep_tm]

# %%
df_third_male = pd.concat([df_chest_tm, df_shoulders_tm, df_legs_tm, df_back_tm], axis = 1)
df_third_male
# Out:
#     Chest_Weight  Chest_Repetitions  Shoulders_Weight  Shoulders_Repetitions  \
# 0             51                  8                 7                      8
# 1             51                 10                 7                      9
# 2             52                  8                 7                     10
# 3             53                  8                 7                     11
# 4             54                  8                 8                      8
# ..           ...                ...               ...                    ...
# 95           116                  8                20                      8
# 96           116                 10                20                      9
# 97           117                  8                20                     10
# 98           119                  8                20                     11
# 99           119                 10                20                     12
#
# ...

# %% [markdown]
# ## Fourth male user (name = Clement)

# %% [markdown]
# ### Chest exercise data

# %%
chest_4m = np.random.randint(30, 96, num_values)
chest_4m = np.sort(chest_4m)
chest_rep_4m = []
chest_rc_4m = {}
for rep in chest_4m:
    if rep not in chest_rc_4m:
        chest_rc_4m[rep] = 8
    else:
        chest_rc_4m[rep] += 2
    chest_rep_4m.append(chest_rc_4m[rep])
df_chest_4m = pd.DataFrame({'Chest_Weight': chest_4m, 'Chest_Repetitions': chest_rep_4m})

# %% [markdown]
# ### Shoulders exercise data

# %%
shoulders_4m = np.random.randint(6, 13, num_values)
shoulders_4m = np.sort(shoulders_4m)
shoulders_rep_4m = []
shoulders_rc_4m = {}
for rep in shoulders_4m:
    if rep not in shoulders_rc_4m:
        shoulders_rc_4m[rep] = 8
    else:
        shoulders_rc_4m[rep] += 1
    if shoulders_rc_4m[rep] > 15:
        shoulders_rc_4m[rep] = 15
    shoulders_rep_4m.append(shoulders_rc_4m[rep])
df_shoulders_4m = pd.DataFrame({'Shoulders_Weight': shoulders_4m, 'Shoulders_Repetitions': shoulders_rep_4m})

# %% [markdown]
# ### Legs exercise data

# %%
legs_4m = np.random.randint(30, 101, num_values)
legs_4m = np.sort(legs_4m)
legs_rep_4m = []
legs_rc_4m = {}
for rep in legs_4m:
    if rep not in legs_rc_4m:
        legs_rc_4m[rep] = 8
    else:
        legs_rc_4m[rep] += 2
    legs_rep_4m.append(legs_rc_4m[rep])
df_legs_4m = pd.DataFrame({'Legs_Weight': legs_4m, 'Legs_Repetitions': legs_rep_4m})

# %% [markdown]
# ### Back exercise data

# %%
back_4m = np.random.randint(20, 71, num_values)
back_4m = np.sort(back_4m)
back_rep_4m = []
back_rc_4m = {}
for rep in back_4m:
    if rep not in back_rc_4m:
        back_rc_4m[rep] = 8
    else:
        back_rc_4m[rep] += 2
    back_rep_4m.append(back_rc_4m[rep])
df_back_4m = pd.DataFrame({'Back_Weight': back_4m, 'Back_Repetitions': back_rep_4m})

# %% [markdown]
# ### Creation of full body data

# %%
list_clement = [chest_4m, chest_rep_4m, shoulders_4m, shoulders_rep_4m, legs_4m, legs_rep_4m, back_4m, back_rep_4m]

# %%
df_fourth_male = pd.concat([df_chest_4m, df_shoulders_4m, df_legs_4m, df_back_4m], axis = 1)
df_fourth_male
# Out:
#     Chest_Weight  Chest_Repetitions  Shoulders_Weight  Shoulders_Repetitions  \
# 0             33                  8                 6                      8
# 1             33                 10                 6                      9
# 2             33                 12                 6                     10
# 3             34                  8                 6                     11
# 4             34                 10                 6                     12
# ..           ...                ...               ...                    ...
# 95            93                  8                12                     15
# 96            93                 10                12                     15
# 97            93                 12                12                     15
# 98            95                  8                12                     15
# 99            95                 10                12                     15
#
# ...

# %% [markdown]
# # Data exploration

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 5))
sns.lineplot(data=df_first_male, x = 'Chest_Weight', y='Chest_Repetitions', ax = ax1)
ax1.set_title('Robert Chest Improvement', fontsize=15)

sns.lineplot(data=df_second_male, x='Chest_Weight', y='Chest_Repetitions', ax = ax2)
ax2.set_title('Roger Chest Improvement', fontsize=15)

sns.lineplot(data=df_third_male, x='Chest_Weight', y='Chest_Repetitions', ax=ax3)
ax3.set_title('Justin Chest Improvement', fontsize=15)

sns.lineplot(data=df_fourth_male, x='Chest_Weight', y='Chest_Repetitions', ax=ax4)
ax4.set_title('Clement Chest Improvement', fontsize=15)

plt.tight_layout()

# %%
plt.plot(df_first_male['Chest_Weight'])
plt.plot(df_second_male['Chest_Weight'])
plt.plot(df_third_male['Chest_Weight'])
plt.plot(df_fourth_male['Chest_Weight'])
plt.legend(['Robert'])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# This data was created randomly, but assuming the user progresses steadily, throughout 100 sessions for each muscle group.\
# We can see how different the data is depending on the weight chosen, the range of it, and the progressive overload the user does.\
# For example, this data would be convenient for a male user. The weight chosen is quite heavy at first, and grows steadily to a point where it can be considered heavy by most gym-goers.

# %% [markdown]
# Let's try creating a data for a female user. Still taking random numbers, but accordingly to the gender of the user.

# %% [markdown]
# # Creation of female data

# %% [markdown]
# ## First female user

# %% [markdown]
# ### Chest exercise data

# %%
chest_f = np.random.randint(20 * 2, 51 * 2, num_values) / 2
chest_f = np.sort(chest_f)
chest_f_r = []
chest_f_r_c = {}
for rep in chest_f:
    if rep not in chest_f_r_c:
        chest_f_r_c[rep] = 8
    else:
        chest_f_r_c[rep] += 2
    chest_f_r.append(chest_f_r_c[rep])
df_chest_f = pd.DataFrame({'Chest_Weight': chest_f, 'Chest_Repetitions': chest_f_r})

# %% [markdown]
# ### Shoulders exercise data

# %%
shoulders_f = np.random.randint(4, 11, num_values)
shoulders_f = np.sort(shoulders_f)
shoulders_f_r = []
shoulders_f_r_c = {}
for rep in shoulders_f:
    if rep not in shoulders_f_r_c:
        shoulders_f_r_c[rep] = 8
    else:
        shoulders_f_r_c[rep] += 1
    if shoulders_f_r_c[rep] > 15:
        shoulders_f_r_c[rep] = 15
    shoulders_f_r.append(shoulders_f_r_c[rep])
df_shoulders_f = pd.DataFrame({'Shoulders_Weight': shoulders_f, 'Shoulders_Repetitions': shoulders_f_r})

# %% [markdown]
# ### Legs exercise data

# %%
legs_f = np.random.randint(30 * 2, 71 * 2, num_values) / 2
legs_f = np.sort(legs_f)
legs_f_r = []
legs_f_r_c = {}
for rep in legs_f:
    if rep not in legs_f_r_c:
        legs_f_r_c[rep] = 8
    else:
        legs_f_r_c[rep] += 2
    legs_f_r.append(legs_f_r_c[rep])
df_legs_f = pd.DataFrame({'Legs_Weight': legs_f, 'Legs_Repetitions': legs_f_r})

# %% [markdown]
# ### Back exercise data

# %%
back_f = np.random.randint(10 * 2, 41 * 2, num_values) / 2
back_f = np.sort(back_f)
back_f_r = []
back_f_r_c = {}
for rep in back_f:
    if rep not in back_f_r_c:
        back_f_r_c[rep] = 8
    else:
        back_f_r_c[rep] += 2
    back_f_r.append(back_f_r_c[rep])
df_back_f = pd.DataFrame({'Back_Weight': back_f, 'Back_Repetitions': back_f_r})

# %% [markdown]
# ### Creation of full body data

# %%
list_julia = [chest_f, chest_f_r, shoulders_f, shoulders_f_r, legs_f, legs_f_r, back_f, back_f_r]

# %%
df_body_f = pd.concat([df_chest_f, df_shoulders_f, df_legs_f, df_back_f], axis = 1)
df_body_f.head()
# Out:
#    Chest_Weight  Chest_Repetitions  Shoulders_Weight  Shoulders_Repetitions  \
# 0          20.0                  8                 4                      8
# 1          20.5                  8                 4                      9
# 2          21.0                  8                 4                     10
# 3          21.5                  8                 4                     11
# 4          21.5                 10                 4                     12
#
#    Legs_Weight  Legs_Repetitions  Back_Weight  Back_Repetitions
# 0         30.0                 8         10.0                 8
# 1         30.5                 8         10.5                 8
# 2         31.5                 8         11.0                 8
# 3         31.5                10         11.0                10
# 4         31.5                12         11.5                 8

# %% [markdown]
# # Data exploration

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12,5))

sns.lineplot(df_chest_f, x='Chest_Weight', y='Chest_Repetitions', ax=ax1)
ax1.set_title('Chest Improvement')

sns.lineplot(df_shoulders_f, x='Shoulders_Weight', y='Shoulders_Repetitions', ax=ax2)
ax2.set_title('Shoulders Improvement')

sns.lineplot(df_legs_f, x='Legs_Weight', y='Legs_Repetitions', ax=ax3)
ax3.set_title('Legs Improvement')

sns.lineplot(df_back_f, x='Back_Weight', y='Back_Repetitions', ax=ax4)
ax4.set_title('Back Improvement')

plt.tight_layout()

# %% [markdown]
# Although the data is still randomly created, the general consensus is that females are physically weaker than male. This is why I've deliberately chosen lower weights.\
# Contrary to its male counterpart, we can see that the female user would stagnate much more on chest and back, and this, due to the lower range of weights. On the contrary, males tend to stagnate more for the legs. Thus, the model should take this into account too.

# %%
arrays = [
    np.array(['Robert', 'Robert', 'Robert', 'Robert', 'Robert', 'Robert', 'Robert', 'Robert']),
    np.array(['Chest', 'Chest', 'Shoulders', 'Shoulders', 'Legs', 'Legs', 'Back', 'Back']),
    np.array(['Chest_Weight', 'Chest_Repetitions', 'Shoulders_Weight', 'Shoulders_Repetitions', 'Legs_Weight', 
              'Legs_Repetitions', 'Back_Weight', 'Back_Repetitions'])
]
index = pd.MultiIndex.from_arrays(arrays, names=('Name', 'Exercise', 'Metric'))
df_robert = pd.DataFrame(list_robert, index=index)
df_robert
# Out:
#                                         0   1   2   3   4   5   6   7   8   \
# Name   Exercise  Metric
# Robert Chest     Chest_Weight           60  60  60  60  60  60  60  61  61
#                  Chest_Repetitions       8  10  12  14  16  18  20   8  10
#        Shoulders Shoulders_Weight        6   6   6   6   6   6   6   6   6
#                  Shoulders_Repetitions   8   9  10  11  12  13  14  15  15
#        Legs      Legs_Weight            60  61  62  62  63  63  63  63  65
#                  Legs_Repetitions        8   8   8   9   8   9  10  11   8
#        Back      Back_Weight            20  20  20  21  23  24  24  25  26
#                  Back_Repetitions        8   8   8   9   8   9  10  11   8
#
#                                         9   ...   90   91   92   93   94   95  \
# Name   Exercise  Metric                     ...
# Robert Chest     Chest_Weight           61  ...   97   98   98   98   99   99
# ...

# %%
arrays = [
    np.array(['Julia', 'Julia', 'Julia', 'Julia', 'Julia', 'Julia', 'Julia', 'Julia']),
    np.array(['Chest', 'Chest', 'Shoulders', 'Shoulders', 'Legs', 'Legs', 'Back', 'Back']),
    np.array(['Chest_Weight', 'Chest_Repetitions', 'Shoulders_Weight', 'Shoulders_Repetitions', 'Legs_Weight', 
              'Legs_Repetitions', 'Back_Weight', 'Back_Repetitions'])
]
index = pd.MultiIndex.from_arrays(arrays, names=('Name', 'Exercise', 'Metric'))
df_julia = pd.DataFrame(list_julia, index=index)
df_julia
# Out:
#                                          0     1     2     3     4     5   \
# Name  Exercise  Metric
# Julia Chest     Chest_Weight           20.0  20.5  21.0  21.5  21.5  22.0
#                 Chest_Repetitions       8.0   8.0   8.0   8.0  10.0   8.0
#       Shoulders Shoulders_Weight        4.0   4.0   4.0   4.0   4.0   4.0
#                 Shoulders_Repetitions   8.0   9.0  10.0  11.0  12.0  13.0
#       Legs      Legs_Weight            30.0  30.5  31.5  31.5  31.5  32.0
#                 Legs_Repetitions        8.0   8.0   8.0  10.0  12.0   8.0
#       Back      Back_Weight            10.0  10.5  11.0  11.0  11.5  11.5
#                 Back_Repetitions        8.0   8.0   8.0  10.0   8.0  10.0
#
#                                          6     7     8     9   ...    90  \
# Name  Exercise  Metric                                         ...
# Julia Chest     Chest_Weight           22.0  23.0  23.0  23.0  ...  47.5
# ...

# %%
df_rob_jul = pd.concat([df_robert, df_julia])
df_rob_jul
# Out:
#                                           0     1     2     3     4     5   \
# Name   Exercise  Metric
# Robert Chest     Chest_Weight           60.0  60.0  60.0  60.0  60.0  60.0
#                  Chest_Repetitions       8.0  10.0  12.0  14.0  16.0  18.0
#        Shoulders Shoulders_Weight        6.0   6.0   6.0   6.0   6.0   6.0
#                  Shoulders_Repetitions   8.0   9.0  10.0  11.0  12.0  13.0
#        Legs      Legs_Weight            60.0  61.0  62.0  62.0  63.0  63.0
#                  Legs_Repetitions        8.0   8.0   8.0   9.0   8.0   9.0
#        Back      Back_Weight            20.0  20.0  20.0  21.0  23.0  24.0
#                  Back_Repetitions        8.0   8.0   8.0   9.0   8.0   9.0
# Julia  Chest     Chest_Weight           20.0  20.5  21.0  21.5  21.5  22.0
#                  Chest_Repetitions       8.0   8.0   8.0   8.0  10.0   8.0
#        Shoulders Shoulders_Weight        4.0   4.0   4.0   4.0   4.0   4.0
# ...

# %%
plt.scatter(df_rob_jul.loc[('Robert', 'Chest', 'Chest_Weight')], y=df_rob_jul.loc[('Robert', 'Chest', 'Chest_Repetitions')])
plt.scatter(df_rob_jul.loc[('Julia', 'Chest', 'Chest_Weight')], y=df_rob_jul.loc[('Julia', 'Chest', 'Chest_Repetitions')])
